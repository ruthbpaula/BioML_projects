# %%
import numpy as np
# import scipy.ndimage as ndimage
import scipy
import matplotlib.pyplot as plt
# %matplotlib inline
plt.gray()

# %%
import PIL
img=np.array(PIL.Image.open("img3.tif"))
# img=img[:-100,:,:]

# %%
from skimage.filters import sobel
plt.figure(figsize=(20,10))

data=np.dot(img[...,:3],[.299,.587,.114])
# data=scipy.ndimage.minimum_filter(data,7)
dvalue=data[data>.01].flatten()
data[data<.01]=np.max(data)
elevation_map = sobel(data)

plt.subplot(1,2,1)
plt.imshow(data)
plt.subplot(1,2,2)
plt.imshow(elevation_map)

# %%
markers = np.zeros_like(data)


# data=scipy.ndimage.minimum_filter(data,7)
databin=data>(np.mean(dvalue)+.0*np.std(dvalue))


databin=scipy.ndimage.binary_opening(databin,iterations=5)
# 
markers[data < (np.mean(data)-0*np.std(data))] = 1
markers[databin] = 2

# plt.imshow(markers)
from skimage.morphology import watershed
segmentation = watershed(elevation_map, markers)-1


seg_open=scipy.ndimage.binary_opening(segmentation,iterations=7)

plt.figure(figsize=(20,10))
plt.subplot(1,2,1)
plt.imshow(segmentation)
plt.subplot(1,2,2)
plt.imshow(seg_open)

# %%
plt.figure(figsize=(20,10))

lab,nlb=scipy.ndimage.label(seg_open)
area=scipy.ndimage.sum(seg_open,lab,range(nlb))
seg_hideedge=seg_open.copy()
# for a in np.where(area>25000)[0]:
#     seg_hideedge[lab == a]=0
for a in np.where(area<1000)[0]:
    seg_hideedge[lab == a]=0

plt.subplot(1,2,1)
plt.imshow(seg_open)
plt.subplot(1,2,2)
plt.imshow(seg_hideedge)
scipy.misc.imsave('outfile.jpg', seg_hideedge)

# lab
# plt.imshow()
# pts=np.array(scipy.ndimage.center_of_mass(data,lab,range(nlb))).astype(int)
# # pts=pts.astype(np.uint16)
# sds=np.zeros_like(data)
# for p in pts: sds[p[0],[[1]]]=1
# print np.sum(sds)
# Out:
# C:\Users\ruthb\anaconda3\envs\python2\lib\site-packages\ipykernel_launcher.py:15: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#   from ipykernel import kernelapp as app
# TypeErrorTraceback (most recent call last)
# <ipython-input-5-eb2247c42e9b> in <module>()
#      13 plt.subplot(1,2,2)
#      14 plt.imshow(seg_hideedge)
# ---> 15 scipy.misc.imsave('outfile.jpg', seg_hideedge)
#      16
#      17 # lab
#
# C:\Users\ruthb\anaconda3\envs\python2\lib\site-packages\numpy\lib\utils.pyc in newfunc(*args, **kwds)
#      99             """`arrayrange` is deprecated, use `arange` instead!"""
#     100             warnings.warn(depdoc, DeprecationWarning, stacklevel=2)
# --> 101             return func(*args, **kwds)
#     102
#     103         newfunc = _set_function_name(newfunc, old_name)
#
# C:\Users\ruthb\anaconda3\envs\python2\lib\site-packages\scipy\misc\pilutil.pyc in imsave(name, arr, format)
#     215
#     216     """
# --> 217     im = toimage(arr, channel_axis=2)
#     218     if format is None:
#     219         im.save(name)
#
# C:\Users\ruthb\anaconda3\envs\python2\lib\site-packages\numpy\lib\utils.pyc in newfunc(*args, **kwds)
#      99             """`arrayrange` is deprecated, use `arange` instead!"""
#     100             warnings.warn(depdoc, DeprecationWarning, stacklevel=2)
# --> 101             return func(*args, **kwds)
#     102
#     103         newfunc = _set_function_name(newfunc, old_name)
#
# C:\Users\ruthb\anaconda3\envs\python2\lib\site-packages\scipy\misc\pilutil.pyc in toimage(arr, high, low, cmin, cmax, pal, mode, channel_axis)
#     335         if mode in [None, 'L', 'P']:
#     336             bytedata = bytescale(data, high=high, low=low,
# --> 337                                  cmin=cmin, cmax=cmax)
#     338             image = Image.frombytes('L', shape, bytedata.tostring())
#     339             if pal is not None:
#
# C:\Users\ruthb\anaconda3\envs\python2\lib\site-packages\numpy\lib\utils.pyc in newfunc(*args, **kwds)
#      99             """`arrayrange` is deprecated, use `arange` instead!"""
#     100             warnings.warn(depdoc, DeprecationWarning, stacklevel=2)
# --> 101             return func(*args, **kwds)
#     102
#     103         newfunc = _set_function_name(newfunc, old_name)
#
# C:\Users\ruthb\anaconda3\envs\python2\lib\site-packages\scipy\misc\pilutil.pyc in bytescale(data, cmin, cmax, high, low)
#      95         cmax = data.max()
#      96
# ---> 97     cscale = cmax - cmin
#      98     if cscale < 0:
#      99         raise ValueError("`cmax` should be larger than `cmin`.")
#
# TypeError: numpy boolean subtract, the `-` operator, is deprecated, use the bitwise_xor, the `^` operator, or the logical_xor function instead.

# %%
plt.figure(figsize=(20,10),frameon=False)
toshow=np.transpose(np.array([seg_hideedge*0,seg_hideedge*0,seg_hideedge*1,seg_hideedge*0+1]),(1,2,0))
print np.shape(toshow)
print np.shape(img)
plt.imshow(toshow)
plt.hold(True)
plt.imshow(img,alpha=.7)

# %%
# print np.sum(seg_hideedge==1)/np.sum(seg_hideedge==0)
edge=float((len(data.flatten())-len(dvalue)))
print float(np.sum(seg_hideedge==1)-edge)/float(len(dvalue))
